# %% [markdown]
# # **Laura Tambwe Mwibashiye**
#
# # **DATA 4380: Data Problems**
# # **Homework 1**

# %% [markdown]
# ## **Setup**

# %% [raw]
# ## 1.
#
# (base) lauratm@MBP-de-Laura ~ % python3 --version
# Python 3.12.7
# (base) lauratm@MBP-de-Laura ~ % pip3 list | grep -E "jupyter|numpy|pandas"
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.10.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.14.1
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.2.5
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.27.3
# jupyterlab-widgets                1.0.0
# lckr_jupyterlab_variableinspector 3.1.0
# numpy                             1.26.4
# numpydoc                          1.7.0
# pandas                            2.2.2
# (base) lauratm@MBP-de-Laura ~ % jupyter notebook
# ...

# %% [raw]
# ## 2.
#
# (base) lauratm@MBP-de-Laura ~ % brew install git
# ...
# (base) lauratm@MBP-de-Laura ~ % ssh-keygen -t ed25519 -C "lmwibashiye@gmail.com"
# Generating public/private ed25519 key pair.
# Enter file in which to save the key (/Users/lauratm/.ssh/id_ed25519):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /Users/lauratm/.ssh/id_ed25519
# Your public key has been saved in /Users/lauratm/.ssh/id_ed25519.pub
# ...
# (base) lauratm@MBP-de-Laura ~ %  eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Agent pid 46884
# Identity added: /Users/lauratm/.ssh/id_ed25519 (lmwibashiye@gmail.com)
# (base) lauratm@MBP-de-Laura ~ % pbcopy < ~/.ssh/id_ed25519.pub
# (base) lauratm@MBP-de-Laura ~ % ssh -T git@github.com
# Hi MwTLaura! You've successfully authenticated, but GitHub does not provide shell access.

# %% [raw]
# (base) lauratm@MBP-de-Laura ~ % git clone git@github.com:MwTLaura/Data4380.Summer2025.git
# Cloning into 'Data4380.Summer2025'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 24 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 8.24 KiB | 2.75 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %% [raw]
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Successful demo for Data 4380" > demo.txt
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % git add demo.txt
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % git commit -m "Completed homework demo"
# [main dd139b1] Completed homework demo
#  1 file changed, 1 insertion(+)
#  create mode 100644 demo.txt
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % git push
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 311 bytes | 311.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:MwTLaura/Data4380.Summer2025.git
#    388e91f..dd139b1  main -> main

# %% [raw]
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ls -R
# Homework	Projects	README.md	demo.txt
#
# ./Homework:
# Homework 1	README.md
#
# ./Homework/Homework 1:
# README.md
#
# ./Projects:
# Computer Vision Project		README.md
# Large Language Model Project	Tabular Project
#
# ./Projects/Computer Vision Project:
# README.md
#
# ./Projects/Large Language Model Project:
# README.md
#
# ./Projects/Tabular Project:
# README.md

# %% [raw]
# ## 3.
#
# (base) lauratm@MBP-de-Laura ~ % pip install kaggle
# Collecting kaggle
# ...
# Successfully installed kaggle-1.7.4.5
#
# (base) lauratm@MBP-de-Laura ~ % mkdir -p ~/.kaggle
# (base) lauratm@MBP-de-Laura ~ % mv ~/Desktop/kaggle.json ~/.kaggle/
# (base) lauratm@MBP-de-Laura ~ % chmod 600 ~/.kaggle/kaggle.json

# %% [raw]
# ## 4.
#
# (base) lauratm@MBP-de-Laura ~ % mkdir -p ~/datasets/Data4380
# (base) lauratm@MBP-de-Laura ~ % unzip ~/Downloads/datasets.zip -d ~/datasets/Data4380/
# Archive:  /Users/lauratm/Downloads/datasets.zip
# ...
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mv ~/datasets/Data4380.Summer2025_data/datasets/* ~/datasets/Data4380.Summer2025_data/
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % rmdir ~/datasets/Data4380.Summer2025_data/datasets
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ls ~/datasets/Data4380.Summer2025_data/
# Heart_Disease_Prediction.csv
# ...
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mkdir -p kaggle_data
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ln -s ~/datasets/Data4380.Summer2025_data kaggle_data/raw_data
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ls kaggle_data/raw_data/
# Heart_Disease_Prediction.csv
# Housing.csv
# Mall_Customers.csv
# Titanic-Dataset.csv
# breast-cancer-wisconsin-data_data.csv
# cancer patient data sets.csv
# car_web_scraped_dataset.csv
# diabetes_prediction_dataset.csv
# diabetes_prediction_dataset_1000.csv
# solution.src
# starbucks.csv
# world all university rank and rank score.csv
# zip_files
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "kaggle_data/raw_data/" >> .gitignore
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "*.csv" >> .gitignore
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "*.zip" >> .gitignore

# %% [raw]
# ## 5.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ln -s ~/datasets/Data4380.Summer2025_data Homework/datasets
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % ls Homework/datasets/
# Heart_Disease_Prediction.csv
# Housing.csv
# Mall_Customers.csv
# Titanic-Dataset.csv
# breast-cancer-wisconsin-data_data.csv
# cancer patient data sets.csv
# car_web_scraped_dataset.csv
# diabetes_prediction_dataset.csv
# diabetes_prediction_dataset_1000.csv
# solution.src
# starbucks.csv
# world all university rank and rank score.csv
# zip_files
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Homework/datasets/" >> .gitignore
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "*.csv" >> .gitignore
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cat .gitignore
# kaggle_data/raw_data/
# *.csv
# *.zip
# Homework/datasets/
# *.csv

# %%
import os
import pandas as pd
DATA_ROOT = os.path.expanduser("~/datasets/Data4380.Summer2025_data")
df = pd.read_csv(f"{DATA_ROOT}/Heart_Disease_Prediction.csv")

# %%
df.head(5)
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %% [markdown]
# ## **Exercises**

# %% [raw]
# ## 1.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mv ~/Desktop/datasets.zip ~/datasets/Data4380.Summer2025_data/
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mkdir -p ~/datasets/Data4380.Summer2025_data/zip_archives
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % unzip ~/datasets/Data4380.Summer2025_data/datasets.zip -d ~/datasets/Data4380.Summer2025_data/
# Archive:  /Users/lauratm/datasets/Data4380.Summer2025_data/datasets.zip
# ...
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mv ~/datasets/Data4380.Summer2025_data/datasets/zip_files/*.zip ~/datasets/Data4380.Summer2025_data/zip_archives/
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % mv ~/datasets/Data4380.Summer2025_data/datasets/*.csv ~/datasets/Data4380.Summer2025_data/
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % brew install tree
# ...
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % tree -L 2 ~/datasets/Data4380.Summer2025_data
# /Users/lauratm/datasets/Data4380.Summer2025_data
# ├── Heart_Disease_Prediction.csv
# ├── Housing.csv
# ├── Mall_Customers.csv
# ├── Titanic-Dataset.csv
# ├── breast-cancer-wisconsin-data_data.csv
# ├── cancer patient data sets.csv
# ├── car_web_scraped_dataset.csv
# ├── datasets
# │   ├── solution.src
# │   └── zip_files
# ├── datasets.zip
# ├── diabetes_prediction_dataset.csv
# ├── diabetes_prediction_dataset_1000.csv
# ├── solution.src
# ├── starbucks.csv
# ├── world all university rank and rank score.csv
# ├── zip_archives
# │   ├── breast-cancer.zip
# │   ├── cancer-patients-and-air-pollution-a-new-link.zip
# │   ├── customer-segmentation-tutorial-in-python.zip
# │   ├── diabetes-prediction-dataset.zip
# │   ├── heart-disease-prediction.zip
# │   ├── housing-price-prediction.zip
# │   ├── starbucks.zip
# │   ├── titanic-dataset.zip
# │   ├── used-car-price-prediction.zip
# │   ├── weather-prediction.zip
# │   └── world-all-university-ranking-factors.zip
# └── zip_files
#     ├── breast-cancer.zip
#     ├── cancer-patients-and-air-pollution-a-new-link.zip
#     ├── customer-segmentation-tutorial-in-python.zip
#     ├── diabetes-prediction-dataset.zip
#     ├── heart-disease-prediction.zip
#     ├── housing-price-prediction.zip
#     ├── starbucks.zip
#     ├── titanic-dataset.zip
#     ├── used-car-price-prediction.zip
#     ├── weather-prediction.zip
#     └── world-all-university-ranking-factors.zip
#
# 5 directories, 36 files

# %% [raw]
# ## 2.
#
# # Count lines
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % total_lines=$(wc -l < ~/datasets/Data4380.Summer2025_data/diabetes_prediction_dataset.csv)
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Total lines: $total_lines"
# Total lines:   100001
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % data_lines=$((total_lines - 1))
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % lines_per_file=$((data_lines / 3))
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Lines per file: $lines_per_file"
# Lines per file: 33333
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 1 ~/datasets/Data4380.Summer2025_data/diabetes_prediction_dataset.csv > diabetes_part1.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cp diabetes_part1.csv diabetes_part2.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cp diabetes_part1.csv diabetes_part3.csv
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % tail -n +2 ~/datasets/Data4380.Summer2025_data/diabetes_prediction_dataset.csv | head -n $lines_per_file >> diabetes_part1.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % tail -n +$((lines_per_file + 2)) ~/datasets/Data4380.Summer2025_data/diabetes_prediction_dataset.csv | head -n $lines_per_file >> diabetes_part2.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % tail -n +$((lines_per_file * 2 + 2)) ~/datasets/Data4380.Summer2025_data/diabetes_prediction_dataset.csv >> diabetes_part3.csv
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Part 1 lines:" && wc -l < diabetes_part1.csv
# Part 1 lines:
#    33334
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Part 2 lines:" && wc -l < diabetes_part2.csv
# Part 2 lines:
#    33334
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Part 3 lines:" && wc -l < diabetes_part3.csv
# Part 3 lines:
#    33335

# %% [raw]
# ## 3.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 1 ~/datasets/Data4380.Summer2025_data/Heart_Disease_Prediction.csv > heart_presence.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cp heart_presence.csv heart_absence.csv
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % grep ",Presence$" ~/datasets/Data4380.Summer2025_data/Heart_Disease_Prediction.csv >> heart_presence.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % grep ",Absence$" ~/datasets/Data4380.Summer2025_data/Heart_Disease_Prediction.csv >> heart_absence.csv
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Presence cases:" && wc -l heart_presence.csv
# Presence cases:
#        2 heart_presence.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Absence cases:" && wc -l heart_absence.csv
# Absence cases:
#        1 heart_absence.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 3 heart_presence.csv
# Age,Sex,Chest pain type,BP,Cholesterol,FBS over 120,EKG results,Max HR,Exercise angina,ST depression,Slope of ST,Number of vessels fluro,Thallium,Heart Disease
# 67,1,4,160,286,0,2,108,1,1.5,2,3,3,Presence
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 3 heart_absence.csv
# Age,Sex,Chest pain type,BP,Cholesterol,FBS over 120,EKG results,Max HR,Exercise angina,ST depression,Slope of ST,Number of vessels fluro,Thallium,Heart Disease

# %% [raw]
# ## 4.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % total_cars=$(wc -l < ~/datasets/Data4380.Summer2025_data/car_web_scraped_dataset.csv)
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Total cars: $((total_cars - 1))"
# Total cars: 2840
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % brew install miller
# ...
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % clean_cars=$(mlr --csv grep -i 'no accident' then count ~/datasets/Data4380.Summer2025_data/car_web_scraped_dataset.csv | awk 'NR==2 {print $1}')
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % total_cars=$(mlr --csv count ~/datasets/Data4380.Summer2025_data/car_web_scraped_dataset.csv | awk 'NR==2 {print $1}')
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Clean cars: $clean_cars/$total_cars = $(echo "scale=1; $clean_cars*100/$total_cars" | bc)%"
# Clean cars: 2223/2840 = 78.2%

# %% [raw]
# ## 5.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % perl -F',' -lane '
#     if ($. == 1) { print; next }
#     for (@F) {
#         s/^\s*yes\s*$/1/;
#         s/^\s*no\s*$/0/;
#         s/^\s*furnished\s*$/1/;
#         s/^\s*unfurnished\s*$/0/;
#         s/^\s*semi-furnished\s*$/2/;
#     }
#     print join(",", @F);
# ' ~/datasets/Data4380.Summer2025_data/Housing.csv > Housing_transformed.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Last column transformation check:"
# Last column transformation check:
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % awk -F',' 'NR>1{print $NF}' Housing_transformed.csv | sort | uniq -c
#  178 0
#  140 1
#  227 2

# %% [raw]
# ## 6.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cut -d ',' -f 2- ~/datasets/Data4380.Summer2025_data/Mall_Customers.csv > Mall_Customers_noID.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "Original columns:"
# Original columns:
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 1 ~/datasets/Data4380.Summer2025_data/Mall_Customers.csv
# CustomerID,Gender,Age,Annual Income (k$),Spending Score (1-100)
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "\nNew columns:"
#
# New columns:
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % head -n 1 Mall_Customers_noID.csv
# Gender,Age,Annual Income (k$),Spending Score (1-100)

# %% [raw]
# ## 7.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % cut -d ',' -f2,5,6,7,8 ~/datasets/Data4380.Summer2025_data/"world all university rank and rank score.csv" | \
# tail -n +2 > raw_scores.tmp
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % awk -F ',' '
# BEGIN {
#     print "University,Research,Industry,International,Environment,Total"
# }
# {
#     gsub(/"/, "", $1)
#
#     for (i=2; i<=5; i++) {
#         gsub(/[^0-9.]/, "", $i)
#         if ($i == "") $i = 0  # Handle empty scores
#     }
#
#     printf "\"%s\",%.1f,%.1f,%.1f,%.1f,%.1f\n",
#            $1, $2, $3, $4, $5, $2+$3+$4+$5
# }' raw_scores.tmp > university_score_details.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo "First 3 universities with score details:"
# head -n 4 university_score_details.csv | column -t -s ','
# First 3 universities with score details:
# University                               Research  Industry  International  Environment  Total
# "Massachusetts Institute of Technology"  92.2      99.9      89.6           96.5         378.2
# "Stanford University"                    91.9      100.0     83.5           91.8         367.2
# "Harvard University"                     95.2      69.8      82.1           93.4         340.5

# %% [raw]
# ## 8.
#
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % (head -n 1 ~/datasets/Data4380.Summer2025_data/"cancer patient data sets.csv" && \
# tail -n +2 ~/datasets/Data4380.Summer2025_data/"cancer patient data sets.csv" | \
# sort -t ',' -k3 -n) > cancer_sorted_by_age.csv
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo -e "\n=== Verification ==="
# echo "First 3 sorted records:"
# head -n 4 cancer_sorted_by_age.csv | cut -d ',' -f 1-3 | column -t -s ','
#
# === Verification ===
# First 3 sorted records:
# index  Patient Id  Age
# 130    P215        14
# 19     P115        14
# 241    P315        14
# (base) lauratm@MBP-de-Laura Data4380.Summer2025 % echo -e "\nLast 3 sorted records:"
# tail -n 3 cancer_sorted_by_age.csv | cut -d ',' -f 1-3 | column -t -s ','
#
# Last 3 sorted records:
# 792  P811  73
# 889  P9    73
# 903  P911  73
